# %%
import cv2

# %%
from google.colab import files
file=files.upload()
# Out:
#      <input type="file" id="files-72c98507-d490-4adf-a177-3b7792ae91f3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-72c98507-d490-4adf-a177-3b7792ae91f3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving haarcascade_frontalface_default.xml to haarcascade_frontalface_default (3).xml
# Saving IMG_1683.JPG to IMG_1683 (1).JPG

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
img = cv2.imread('IMG_1683.JPG')

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

faces = face_cascade.detectMultiScale(gray, 1.1, 4)

print(faces)
# Out:
# [[ 353  621  775  775]
#  [1064  753  506  506]
#  [1905 1777  120  120]]

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),8)
    roigray = gray[y:y+h, x:x+w]
    roicolor = img[y:y+h, x:x+w]
plt.grid(None)   
plt.xticks([])
plt.yticks([])
imgplot = plt.imshow(img)
