# %% [markdown]
# <a href="https://colab.research.google.com/github/MushariBahaddad/Artificial_Intelligence_and_Robotic/blob/master/Face_Detection_in_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
from google.colab import files
file=files.upload()
# Out:
#      <input type="file" id="files-9c6b0586-6cf7-4414-8c27-b36b9334f568" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9c6b0586-6cf7-4414-8c27-b36b9334f568">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving haarcascade_frontalface_default.xml to haarcascade_frontalface_default (4).xml
# Saving IMG_0940.JPG to IMG_0940 (1).JPG

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
img = cv2.imread('IMG_0940.JPG')

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

faces = face_cascade.detectMultiScale(gray, 1.1, 4)

print(faces)
# Out:
# [[1636  794  717  717]]

# %%
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),20)
    roigray = gray[y:y+h, x:x+w]
    roicolor = img[y:y+h, x:x+w]
plt.grid(None)   
plt.xticks([])
plt.yticks([])
imgplot = plt.imshow(img)
